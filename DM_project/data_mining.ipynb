# %% [markdown]
# **Data_Mining Mini-project**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder

# %%
df=pd.read_csv("C:/Users/Win8/Desktop/projects 6th sem/DM/restaurant-1-orders.csv")

# %% [markdown]
# **Dataset**

# %%
df
# Out:
#        Order Number        Order Date              Item_Name  Quantity  \
# 0             16118  03-08-2019 20:25          Plain Papadum         2
# 1             16118  03-08-2019 20:25       King Prawn Balti         1
# 2             16118  03-08-2019 20:25            Garlic Naan         1
# 3             16118  03-08-2019 20:25          Mushroom Rice         1
# 4             16118  03-08-2019 20:25    Paneer Tikka Masala         1
# ...             ...               ...                    ...       ...
# 74813          2518  18-05-2016 18:53    House Red wine 75cl         2
# 74814          2503  14-05-2016 19:28    House Red wine 75cl         2
# 74815          2467  10-05-2016 13:18    House Red wine 75cl         2
# 74816          2249  07-04-2016 19:04  House white wine 75cl         1
# 74817          1403  02-10-2015 17:29    House Red wine 75cl         1
#
#        Product Price  Total products
# 0               0.80               6
# 1              12.95               6
# 2               2.95               6
# 3               3.95               6
# 4               8.95               6
# ...              ...             ...
# 74813          17.95               7
# 74814          17.95               6
# 74815          17.95               9
# 74816          17.95               6
# 74817          17.95               9
#
# [74818 rows x 6 columns]

# %% [markdown]
# **Data Preprocessing**

# %%
df=pd.read_csv("restaurant-1-orders.csv")
df.columns=[col.replace(' ','_')for col in df.columns]

# %%
df.head()
# Out:
#    Order_Number        Order_Date            Item_Name  Quantity  \
# 0         16118  03-08-2019 20:25        Plain Papadum         2
# 1         16118  03-08-2019 20:25     King Prawn Balti         1
# 2         16118  03-08-2019 20:25          Garlic Naan         1
# 3         16118  03-08-2019 20:25        Mushroom Rice         1
# 4         16118  03-08-2019 20:25  Paneer Tikka Masala         1
#
#    Product_Price  Total_products
# 0           0.80               6
# 1          12.95               6
# 2           2.95               6
# 3           3.95               6
# 4           8.95               6

# %% [markdown]
# **Data transformation**

# %%
df=df.pivot_table(index='Order_Number',columns='Item_Name',values='Quantity')

# %%
df
# Out:
# Item_Name     Aloo Chaat  Aloo Gobi  Aloo Methi  Baingan Hari Mirch  \
# Order_Number
# 630                  NaN        NaN         NaN                 NaN
# 647                  NaN        NaN         NaN                 NaN
# 648                  NaN        NaN         NaN                 NaN
# 651                  NaN        NaN         NaN                 NaN
# 764                  NaN        NaN         NaN                 NaN
# ...                  ...        ...         ...                 ...
# 16114                NaN        NaN         NaN                 NaN
# 16115                NaN        NaN         NaN                 NaN
# 16116                1.0        NaN         NaN                 NaN
# 16117                NaN        NaN         NaN                 NaN
# 16118                NaN        NaN         NaN                 NaN
#
# Item_Name     Bengal Fish Biryani  Bengal Fish Karahi  Bengal Fry Fish  \
# Order_Number
# 630                           NaN                 NaN              NaN
# 647                           NaN                 NaN              NaN
# 648                           NaN                 NaN              NaN
# 651                           NaN                 NaN              NaN
# 764                           NaN                 NaN              NaN
# ...                           ...                 ...              ...
# 16114                         NaN                 NaN              NaN
# 16115                         NaN                 NaN              NaN
# 16116                         NaN                 NaN              NaN
# 16117                         NaN                 NaN              NaN
# 16118                         NaN                 NaN              NaN
#
# Item_Name     Bengal King Prawn  Bengal Salad  Bhindi Bhajee  ...  \
# Order_Number                                                  ...
# 630                         NaN           NaN            NaN  ...
# 647                         NaN           NaN            NaN  ...
# 648                         NaN           NaN            NaN  ...
# 651                         NaN           NaN            NaN  ...
# 764                         NaN           NaN            NaN  ...
# ...                         ...           ...            ...  ...
# 16114                       NaN           NaN            NaN  ...
# 16115                       NaN           NaN            NaN  ...
# 16116                       NaN           NaN            NaN  ...
# 16117                       NaN           NaN            NaN  ...
# 16118                       NaN           NaN            NaN  ...
#
# Item_Name     Vegetable Rice  Vegetable Roll  Vegetable Samosa  Vindaloo  \
# Order_Number
# 630                      NaN             NaN               NaN       NaN
# 647                      NaN             NaN               NaN       NaN
# 648                      NaN             NaN               NaN       NaN
# 651                      NaN             NaN               NaN       NaN
# 764                      NaN             NaN               NaN       NaN
# ...                      ...             ...               ...       ...
# 16114                    NaN             NaN               NaN       NaN
# 16115                    NaN             NaN               NaN       NaN
# 16116                    NaN             NaN               NaN       NaN
# 16117                    NaN             NaN               NaN       NaN
# 16118                    NaN             NaN               NaN       NaN
#
# Item_Name     Vindaloo - Chicken  Vindaloo - Chicken Tikka  \
# Order_Number
# 630                          NaN                       NaN
# 647                          NaN                       NaN
# 648                          NaN                       NaN
# 651                          NaN                       NaN
# 764                          NaN                       NaN
# ...                          ...                       ...
# 16114                        NaN                       NaN
# 16115                        NaN                       NaN
# 16116                        NaN                       NaN
# 16117                        NaN                       NaN
# 16118                        NaN                       NaN
#
# Item_Name     Vindaloo - King Prawn  Vindaloo - Lamb  Vindaloo - Prawn  \
# Order_Number
# 630                             NaN              NaN               NaN
# 647                             NaN              NaN               NaN
# 648                             NaN              NaN               NaN
# 651                             NaN              NaN               NaN
# 764                             NaN              NaN               NaN
# ...                             ...              ...               ...
# 16114                           NaN              NaN               NaN
# 16115                           NaN              NaN               NaN
# 16116                           NaN              NaN               NaN
# 16117                           NaN              1.0               NaN
# 16118                           NaN              NaN               NaN
#
# Item_Name     Vindaloo Sauce
# Order_Number
# 630                      NaN
# 647                      NaN
# 648                      NaN
# 651                      NaN
# 764                      NaN
# ...                      ...
# 16114                    NaN
# 16115                    NaN
# 16116                    NaN
# 16117                    NaN
# 16118                    NaN
#
# [13397 rows x 248 columns]

# %% [markdown]
# **Data cleaning**

# %%
df=df.fillna(0)

# %%
df.isnull().any()
# Out:
# Item_Name
# Aloo Chaat                  False
# Aloo Gobi                   False
# Aloo Methi                  False
# Baingan Hari Mirch          False
# Bengal Fish Biryani         False
#                             ...
# Vindaloo - Chicken Tikka    False
# Vindaloo - King Prawn       False
# Vindaloo - Lamb             False
# Vindaloo - Prawn            False
# Vindaloo Sauce              False
# Length: 248, dtype: bool

# %%
df.isnull().sum()
# Out:
# Item_Name
# Aloo Chaat                  0
# Aloo Gobi                   0
# Aloo Methi                  0
# Baingan Hari Mirch          0
# Bengal Fish Biryani         0
#                            ..
# Vindaloo - Chicken Tikka    0
# Vindaloo - King Prawn       0
# Vindaloo - Lamb             0
# Vindaloo - Prawn            0
# Vindaloo Sauce              0
# Length: 248, dtype: int64

# %% [markdown]
# **Encoding(data transformation)**

# %%
def one_hot_encode(x):
    if(x <= 0):
        return 0
    if(x >= 1):
        return 1

# %%
df=df.applymap(one_hot_encode)

# %%
df
# Out:
# Item_Name     Aloo Chaat  Aloo Gobi  Aloo Methi  Baingan Hari Mirch  \
# Order_Number
# 630                    0          0           0                   0
# 647                    0          0           0                   0
# 648                    0          0           0                   0
# 651                    0          0           0                   0
# 764                    0          0           0                   0
# ...                  ...        ...         ...                 ...
# 16114                  0          0           0                   0
# 16115                  0          0           0                   0
# 16116                  1          0           0                   0
# 16117                  0          0           0                   0
# 16118                  0          0           0                   0
#
# Item_Name     Bengal Fish Biryani  Bengal Fish Karahi  Bengal Fry Fish  \
# Order_Number
# 630                             0                   0                0
# 647                             0                   0                0
# 648                             0                   0                0
# 651                             0                   0                0
# 764                             0                   0                0
# ...                           ...                 ...              ...
# 16114                           0                   0                0
# 16115                           0                   0                0
# 16116                           0                   0                0
# 16117                           0                   0                0
# 16118                           0                   0                0
#
# Item_Name     Bengal King Prawn  Bengal Salad  Bhindi Bhajee  ...  \
# Order_Number                                                  ...
# 630                           0             0              0  ...
# 647                           0             0              0  ...
# 648                           0             0              0  ...
# 651                           0             0              0  ...
# 764                           0             0              0  ...
# ...                         ...           ...            ...  ...
# 16114                         0             0              0  ...
# 16115                         0             0              0  ...
# 16116                         0             0              0  ...
# 16117                         0             0              0  ...
# 16118                         0             0              0  ...
#
# Item_Name     Vegetable Rice  Vegetable Roll  Vegetable Samosa  Vindaloo  \
# Order_Number
# 630                        0               0                 0         0
# 647                        0               0                 0         0
# 648                        0               0                 0         0
# 651                        0               0                 0         0
# 764                        0               0                 0         0
# ...                      ...             ...               ...       ...
# 16114                      0               0                 0         0
# 16115                      0               0                 0         0
# 16116                      0               0                 0         0
# 16117                      0               0                 0         0
# 16118                      0               0                 0         0
#
# Item_Name     Vindaloo - Chicken  Vindaloo - Chicken Tikka  \
# Order_Number
# 630                            0                         0
# 647                            0                         0
# 648                            0                         0
# 651                            0                         0
# 764                            0                         0
# ...                          ...                       ...
# 16114                          0                         0
# 16115                          0                         0
# 16116                          0                         0
# 16117                          0                         0
# 16118                          0                         0
#
# Item_Name     Vindaloo - King Prawn  Vindaloo - Lamb  Vindaloo - Prawn  \
# Order_Number
# 630                               0                0                 0
# 647                               0                0                 0
# 648                               0                0                 0
# 651                               0                0                 0
# 764                               0                0                 0
# ...                             ...              ...               ...
# 16114                             0                0                 0
# 16115                             0                0                 0
# 16116                             0                0                 0
# 16117                             0                1                 0
# 16118                             0                0                 0
#
# Item_Name     Vindaloo Sauce
# Order_Number
# 630                        0
# 647                        0
# 648                        0
# 651                        0
# 764                        0
# ...                      ...
# 16114                      0
# 16115                      0
# 16116                      0
# 16117                      0
# 16118                      0
#
# [13397 rows x 248 columns]

# %% [markdown]
# **Apriori Algorithm using inbuilt function**

# %%
from mlxtend.frequent_patterns import apriori , association_rules

# %%
frq_items = apriori(df,min_support = 0.05, use_colnames = True)
rules = association_rules(frq_items,metric = "lift" ,min_threshold = 1)
rules = rules.sort_values(['confidence','lift'],ascending=[False,False])

# %%
print(rules)
# Out:
#                        antecedents                     consequents  \
# 44     (Pilau Rice, Mango Chutney)                 (Plain Papadum)
# 29                 (Onion Chutney)                 (Plain Papadum)
# 21                    (Mint Sauce)                 (Plain Papadum)
# 19                 (Mango Chutney)                 (Plain Papadum)
# 2           (Chicken Tikka Masala)                    (Pilau Rice)
# 43  (Plain Papadum, Mango Chutney)                    (Pilau Rice)
# 0                    (Bombay Aloo)                    (Pilau Rice)
# 34                 (Plain Papadum)                    (Pilau Rice)
# 12                    (Mint Sauce)                 (Mango Chutney)
# 15                 (Mango Chutney)                    (Pilau Rice)
# 30                 (Peshwari Naan)                    (Pilau Rice)
# 32                    (Plain Naan)                    (Pilau Rice)
# 22                  (Onion Bhajee)                    (Pilau Rice)
# 42     (Plain Papadum, Pilau Rice)                 (Mango Chutney)
# 18                 (Plain Papadum)                 (Mango Chutney)
# 8                    (Garlic Naan)                    (Pilau Rice)
# 5           (Chicken Tikka Masala)                    (Plain Naan)
# 39                    (Plain Rice)                    (Plain Naan)
# 35                    (Pilau Rice)                 (Plain Papadum)
# 47                 (Mango Chutney)     (Plain Papadum, Pilau Rice)
# 7           (Chicken Tikka Masala)                 (Plain Papadum)
# 27                  (Onion Bhajee)                 (Plain Papadum)
# 33                    (Pilau Rice)                    (Plain Naan)
# 13                 (Mango Chutney)                    (Mint Sauce)
# 17                 (Mango Chutney)                    (Plain Naan)
# 41                    (Plain Rice)                 (Plain Papadum)
# 36                 (Plain Papadum)                    (Plain Naan)
# 37                    (Plain Naan)                 (Plain Papadum)
# 20                 (Plain Papadum)                    (Mint Sauce)
# 24                  (Onion Bhajee)                    (Plain Naan)
# 11                   (Garlic Naan)                 (Plain Papadum)
# 26                 (Plain Papadum)                  (Onion Bhajee)
# 38                    (Plain Naan)                    (Plain Rice)
# 3                     (Pilau Rice)          (Chicken Tikka Masala)
# 9                     (Pilau Rice)                   (Garlic Naan)
# 4                     (Plain Naan)          (Chicken Tikka Masala)
# 23                    (Pilau Rice)                  (Onion Bhajee)
# 6                  (Plain Papadum)          (Chicken Tikka Masala)
# 28                 (Plain Papadum)                 (Onion Chutney)
# 45                 (Plain Papadum)     (Pilau Rice, Mango Chutney)
# 40                 (Plain Papadum)                    (Plain Rice)
# 14                    (Pilau Rice)                 (Mango Chutney)
# 10                 (Plain Papadum)                   (Garlic Naan)
# 25                    (Plain Naan)                  (Onion Bhajee)
# 16                    (Plain Naan)                 (Mango Chutney)
# 1                     (Pilau Rice)                   (Bombay Aloo)
# 46                    (Pilau Rice)  (Plain Papadum, Mango Chutney)
# 31                    (Pilau Rice)                 (Peshwari Naan)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 44            0.073524            0.268418  0.058147    0.790863  2.946382
# 29            0.077032            0.268418  0.058297    0.756783  2.819416
# 21            0.109204            0.268418  0.080839    0.740260  2.757859
# 19            0.154438            0.268418  0.113010    0.731754  2.726172
# 2             0.159215            0.352392  0.085094    0.534459  1.516658
# 43            0.113010            0.352392  0.058147    0.514531  1.460109
# 0             0.130776            0.352392  0.065313    0.499429  1.417253
# 34            0.268418            0.352392  0.133239    0.496385  1.408614
# 12            0.109204            0.154438  0.053743    0.492139  3.186656
# 15            0.154438            0.352392  0.073524    0.476075  1.350981
# 30            0.114578            0.352392  0.053893    0.470358  1.334758
# 32            0.280063            0.352392  0.129133    0.461087  1.308449
# 22            0.179219            0.352392  0.079421    0.443149  1.257544
# 42            0.133239            0.154438  0.058147    0.436415  2.825832
# 18            0.268418            0.154438  0.113010    0.421023  2.726172
# 8             0.196163            0.352392  0.081436    0.415145  1.178075
# 5             0.159215            0.280063  0.064417    0.404594  1.444657
# 39            0.176831            0.280063  0.068150    0.385395  1.376101
# 35            0.352392            0.268418  0.133239    0.378098  1.408614
# 47            0.154438            0.133239  0.058147    0.376510  2.825832
# 7             0.159215            0.268418  0.059864    0.375996  1.400785
# 27            0.179219            0.268418  0.066433    0.370679  1.380975
# 33            0.352392            0.280063  0.129133    0.366448  1.308449
# 13            0.154438            0.109204  0.053743    0.347994  3.186656
# 17            0.154438            0.280063  0.052251    0.338328  1.208043
# 41            0.176831            0.268418  0.056505    0.319544  1.190471
# 36            0.268418            0.280063  0.084795    0.315907  1.127985
# 37            0.280063            0.268418  0.084795    0.302772  1.127985
# 20            0.268418            0.109204  0.080839    0.301168  2.757859
# 24            0.179219            0.280063  0.053296    0.297376  1.061820
# 11            0.196163            0.268418  0.053146    0.270928  1.009352
# 26            0.268418            0.179219  0.066433    0.247497  1.380975
# 38            0.280063            0.176831  0.068150    0.243337  1.376101
# 3             0.352392            0.159215  0.085094    0.241474  1.516658
# 9             0.352392            0.196163  0.081436    0.231095  1.178075
# 4             0.280063            0.159215  0.064417    0.230011  1.444657
# 23            0.352392            0.179219  0.079421    0.225376  1.257544
# 6             0.268418            0.159215  0.059864    0.223026  1.400785
# 28            0.268418            0.077032  0.058297    0.217186  2.819416
# 45            0.268418            0.073524  0.058147    0.216630  2.946382
# 40            0.268418            0.176831  0.056505    0.210512  1.190471
# 14            0.352392            0.154438  0.073524    0.208642  1.350981
# 10            0.268418            0.196163  0.053146    0.197998  1.009352
# 25            0.280063            0.179219  0.053296    0.190299  1.061820
# 16            0.280063            0.154438  0.052251    0.186567  1.208043
# 1             0.352392            0.130776  0.065313    0.185342  1.417253
# 46            0.352392            0.113010  0.058147    0.165007  1.460109
# 31            0.352392            0.114578  0.053893    0.152934  1.334758
#
#     leverage  conviction
# 44  0.038412    3.498097
# 29  0.037620    3.007937
# 21  0.051527    2.816590
# 19  0.071557    2.727284
# 2   0.028988    1.391085
# 43  0.018323    1.333984
# 0   0.019229    1.293738
# 34  0.038650    1.285918
# 12  0.036878    1.664950
# 15  0.019101    1.236070
# 30  0.013516    1.222728
# 32  0.030441    1.201693
# 22  0.016265    1.162981
# 42  0.037570    1.500327
# 18  0.071557    1.460443
# 8   0.012310    1.107295
# 5   0.019827    1.209155
# 39  0.018626    1.171381
# 35  0.038650    1.176361
# 47  0.037570    1.390177
# 7   0.017128    1.172400
# 27  0.018327    1.162493
# 33  0.030441    1.136350
# 13  0.036878    1.366240
# 17  0.008998    1.088057
# 41  0.009041    1.075135
# 36  0.009621    1.052396
# 37  0.009621    1.049272
# 20  0.051527    1.274693
# 24  0.003103    1.024641
# 11  0.000492    1.003443
# 26  0.018327    1.090735
# 38  0.018626    1.087894
# 3   0.028988    1.108447
# 9   0.012310    1.045431
# 4   0.019827    1.091944
# 23  0.016265    1.059586
# 6   0.017128    1.082127
# 28  0.037620    1.179038
# 45  0.038412    1.182679
# 40  0.009041    1.042662
# 14  0.019101    1.068496
# 10  0.000492    1.002287
# 25  0.003103    1.013683
# 16  0.008998    1.039499
# 1   0.019229    1.066981
# 46  0.018323    1.062272
# 31  0.013516    1.045281

# %% [markdown]
# **Manual Implementation of Apriori algorithm**

# %%
import csv
import itertools#for iteration

DataFile = open('C:/Users/Win8/Desktop/projects 6th sem/DM/restaurants-1-orders.csv', 'r')
minsup = 0.1
f2 = "C:/Users/Win8/Desktop/projects 6th sem/DM/Rules.txt"
f1 = "C:/Users/Win8/Desktop/projects 6th sem/DM/FItems.txt"
minconf = 0.39


def L1():
    '''
    Find frequent 1-itemsets
    '''
    #Get all 1-itemsets in the list items and their counts in the dictionary counts
    DataCaptured = csv.reader(DataFile, delimiter=',')
    data = list(DataCaptured)
    for e in data:
        e = sorted(e)
    count = {}
    for items in data:
        for item in items:
            if item not in count:
                count[(item)] = 1
            else:
                count[(item)] = count[(item)] + 1
    #print("C1 Items", count)
    print("C1 Length : ", len(count))
    print()

    #Thresholding
    count2 = {k: v for k, v in count.items() if v >= minsup*9835}
    #print("L1 Items : ", count2)
    print("L1 Length : ", len(count2))
    print()

    return count2, data


def generateCk(Lk_1, flag, data):
    '''
    Generate Ck by joining 2 Lk-1
    '''
    Ck = []

    if flag == 1:
        flag = 0
        for item1 in Lk_1:
            for item2 in Lk_1:
                if item2 > item1:
                    Ck.append((item1, item2))
        print("C2: ", Ck[1:3])
        print("length : ", len(Ck))
        print()

    else:
        for item in Lk_1:
            k = len(item)
        for item1 in Lk_1:
            for item2 in Lk_1:
                if (item1[:-1] == item2[:-1]) and (item1[-1] != item2[-1]):
                    if item1[-1] > item2[-1]:
                        Ck.append(item2 + (item1[-1],))
                    else:
                        Ck.append(item1 + (item2[-1],))
        print("C" + str(k+1) + ": ", Ck[1:3])
        print("Length : ", len(Ck))
        print()
    L = generateLk(set(Ck), data)
    return L, flag


def generateLk(Ck, data):
    '''
    If item in Ck belongs to a transaction,
    it makes it into list Ct
    Then Ct is thresholded to form L
    '''
    count = {}
    for itemset in Ck:
        for transaction in data:
            if all(e in transaction for e in itemset):
                if itemset not in count:
                    count[itemset] = 1
                else:
                    count[itemset] = count[itemset] + 1

    print("Ct Length : ", len(count))
    print()

    count2 = {k: v for k, v in count.items() if v >= minsup*9835}
    print("L Length : ", len(count2))
    print()
    return count2


def rulegenerator(fitems):
    '''
    Generates association rules from the frequent itemsets
    '''
    counter = 0
    for itemset in fitems.keys():
        if isinstance(itemset, str):
            continue
        length = len(itemset)

        union_support = fitems[tuple(itemset)]
        for i in range(1, length):

            lefts = map(list, itertools.combinations(itemset, i))
            for left in lefts:
                if len(left) == 1:
                    if ''.join(left) in fitems:
                        leftcount = fitems[''.join(left)]
                        conf = union_support / leftcount
                else:
                    if tuple(left) in fitems:
                        leftcount = fitems[tuple(left)]
                        conf = union_support / leftcount
                if conf >= minconf:
                    fo = open(f2, "a+")
                    right = list(itemset[:])
                    for e in left:
                        right.remove(e)
                    fo.write(str(left) + ' (' + str(leftcount) + ')' + ' -> ' + str(right) + ' (' + str(fitems[''.join(right)]) + ')' + ' [' + str(conf) + ']' + '\n')
                    print(str(left) + ' -> ' + str(right) + ' (' + str(conf) + ')')
                    counter = counter + 1
                   
                    fo.close()
    print(counter, "rules generated")


def apriori():
    '''
    The runner function
    '''
    L, data = L1()
    flag = 1
    FreqItems = dict(L)
    while(len(L) != 0):
        fo = open(f1, "a+")
        for k, v in L.items():
            fo.write(str(k) + ' >>> ' + str(v) + '\n\n')
        fo.close()

        L, flag = generateCk(L, flag, data)
        FreqItems.update(L)
    rulegenerator(FreqItems)


if __name__ == '__main__':
    apriori()
# Out:
# C1 Length :  9
#
# L1 Length :  9
#
# C2:  [('Plain Rice', 'Vindaloo - Prawn'), ('Special Fried Rice', 'Vindaloo - Prawn')]
# length :  36
#
# Ct Length :  36
#
# L Length :  36
#
# C3:  [('Bhuna - Chicken', 'Curry', 'House white wine 75cl'), ('Bhuna - Chicken', 'Chicken Tikka Balti', 'House white wine 75cl')]
# Length :  168
#
# Ct Length :  84
#
# L Length :  84
#
# C4:  [('House white wine 75cl', 'Lamb Biryani', 'Special Fried Rice', 'Vindaloo - Prawn'), ('Bhuna - Chicken', 'House white wine 75cl', 'Korma - Lamb', 'Plain Rice')]
# Length :  252
#
# Ct Length :  126
#
# L Length :  0
#
# ['Plain Rice'] -> ['Special Fried Rice'] (0.4615085536547434)
# ['Special Fried Rice'] -> ['Plain Rice'] (0.46521653929061335)
# ['Bhuna - Chicken'] -> ['House white wine 75cl'] (0.4530451866404715)
# ['House white wine 75cl'] -> ['Bhuna - Chicken'] (0.456905092133941)
# ['Lamb Biryani'] -> ['Vindaloo - Prawn'] (0.45897187196896216)
# ['Vindaloo - Prawn'] -> ['Lamb Biryani'] (0.4634671890303624)
# ['Chicken Tikka Balti'] -> ['Korma - Lamb'] (0.4606499608457322)
# ['Korma - Lamb'] -> ['Chicken Tikka Balti'] (0.46483603318846306)
# ['Korma - Lamb'] -> ['Special Fried Rice'] (0.4660213354405373)
# ['Special Fried Rice'] -> ['Korma - Lamb'] (0.46227709190672156)
# ['Korma - Lamb'] -> ['Vindaloo - Prawn'] (0.46009482418016595)
# ['Vindaloo - Prawn'] -> ['Korma - Lamb'] (0.45621939275220375)
# ['Curry'] -> ['Lamb Biryani'] (0.4711864406779661)
# ['Lamb Biryani'] -> ['Curry'] (0.45838991270611057)
# ['Plain Rice'] -> ['Vindaloo - Prawn'] (0.46170295489891133)
# ['Vindaloo - Prawn'] -> ['Plain Rice'] (0.465230166503428)
# ['Bhuna - Chicken'] -> ['Curry'] (0.44734774066797645)
# ['Curry'] -> ['Bhuna - Chicken'] (0.4540378863409771)
# ['Curry'] -> ['Plain Rice'] (0.4590229312063809)
# ['Plain Rice'] -> ['Curry'] (0.4475116640746501)
# ['House white wine 75cl'] -> ['Special Fried Rice'] (0.46998216762433126)
# ['Special Fried Rice'] -> ['House white wine 75cl'] (0.4648246129727611)
# ['Chicken Tikka Balti'] -> ['Special Fried Rice'] (0.4643696162881754)
# ['Special Fried Rice'] -> ['Chicken Tikka Balti'] (0.4648246129727611)
# ['House white wine 75cl'] -> ['Korma - Lamb'] (0.4555181295819299)
# ['Korma - Lamb'] -> ['House white wine 75cl'] (0.45416831291979454)
# ['Chicken Tikka Balti'] -> ['Lamb Biryani'] (0.4610415035238841)
# ['Lamb Biryani'] -> ['Chicken Tikka Balti'] (0.4568380213385063)
# ['Bhuna - Chicken'] -> ['Chicken Tikka Balti'] (0.45540275049115914)
# ['Chicken Tikka Balti'] -> ['Bhuna - Chicken'] (0.4537979639780736)
# ['Curry'] -> ['House white wine 75cl'] (0.46141575274177465)
# ['House white wine 75cl'] -> ['Curry'] (0.4584901921933822)
# ['Lamb Biryani'] -> ['Special Fried Rice'] (0.4599418040737148)
# ['Special Fried Rice'] -> ['Lamb Biryani'] (0.464628649813835)
# ['House white wine 75cl'] -> ['Plain Rice'] (0.47057658014662174)
# ['Plain Rice'] -> ['House white wine 75cl'] (0.46170295489891133)
# ['Bhuna - Chicken'] -> ['Vindaloo - Prawn'] (0.4620825147347741)
# ['Vindaloo - Prawn'] -> ['Bhuna - Chicken'] (0.4607247796278159)
# ['Chicken Tikka Balti'] -> ['Plain Rice'] (0.46867658574784654)
# ['Plain Rice'] -> ['Chicken Tikka Balti'] (0.4653965785381026)
# ['Bhuna - Chicken'] -> ['Special Fried Rice'] (0.4577603143418468)
# ['Special Fried Rice'] -> ['Bhuna - Chicken'] (0.456594160297864)
# ['Special Fried Rice'] -> ['Vindaloo - Prawn'] (0.46502057613168724)
# ['Vindaloo - Prawn'] -> ['Special Fried Rice'] (0.46483839373163566)
# ['Curry'] -> ['Vindaloo - Prawn'] (0.4534396809571286)
# ['Vindaloo - Prawn'] -> ['Curry'] (0.4454456415279138)
# ['Bhuna - Chicken'] -> ['Lamb Biryani'] (0.4644400785854617)
# ['Lamb Biryani'] -> ['Bhuna - Chicken'] (0.4585838991270611)
# ['Chicken Tikka Balti'] -> ['Curry'] (0.45458104933437743)
# ['Curry'] -> ['Chicken Tikka Balti'] (0.4630109670987039)
# ['Bhuna - Chicken'] -> ['Korma - Lamb'] (0.4504911591355599)
# ['Korma - Lamb'] -> ['Bhuna - Chicken'] (0.4529830106677203)
# ['Bhuna - Chicken'] -> ['Plain Rice'] (0.45638506876227897)
# ['Plain Rice'] -> ['Bhuna - Chicken'] (0.4515940902021773)
# ['Chicken Tikka Balti'] -> ['Vindaloo - Prawn'] (0.46808927173061865)
# ['Vindaloo - Prawn'] -> ['Chicken Tikka Balti'] (0.4683643486777669)
# ['Chicken Tikka Balti'] -> ['House white wine 75cl'] (0.45086139389193425)
# ['House white wine 75cl'] -> ['Chicken Tikka Balti'] (0.4563106796116505)
# ['Lamb Biryani'] -> ['Plain Rice'] (0.46731328806983513)
# ['Plain Rice'] -> ['Lamb Biryani'] (0.46831259720062207)
# ['House white wine 75cl'] -> ['Lamb Biryani'] (0.4717654051912027)
# ['Lamb Biryani'] -> ['House white wine 75cl'] (0.4618816682832202)
# ['Korma - Lamb'] -> ['Plain Rice'] (0.46029237455551164)
# ['Plain Rice'] -> ['Korma - Lamb'] (0.45295489891135304)
# ['Curry'] -> ['Special Fried Rice'] (0.46939182452642075)
# ['Special Fried Rice'] -> ['Curry'] (0.4612972761120909)
# ['Curry'] -> ['Korma - Lamb'] (0.46580259222333004)
# ['Korma - Lamb'] -> ['Curry'] (0.46147767680758595)
# ['House white wine 75cl'] -> ['Vindaloo - Prawn'] (0.462056667327125)
# ['Vindaloo - Prawn'] -> ['House white wine 75cl'] (0.45680705190989224)
# ['Korma - Lamb'] -> ['Lamb Biryani'] (0.4632556301856974)
# ['Lamb Biryani'] -> ['Korma - Lamb'] (0.45489815712900095)
# ['House white wine 75cl', 'Lamb Biryani'] -> ['Vindaloo - Prawn'] (0.45695086098278037)
# ['House white wine 75cl', 'Vindaloo - Prawn'] -> ['Lamb Biryani'] (0.4665523156089194)
# ['Lamb Biryani', 'Vindaloo - Prawn'] -> ['House white wine 75cl'] (0.45984784446322907)
# ['House white wine 75cl', 'Special Fried Rice'] -> ['Vindaloo - Prawn'] (0.46669477234401346)
# ['House white wine 75cl', 'Vindaloo - Prawn'] -> ['Special Fried Rice'] (0.47469982847341335)
# ['Special Fried Rice', 'Vindaloo - Prawn'] -> ['House white wine 75cl'] (0.4664981036662453)
# ['Korma - Lamb', 'Special Fried Rice'] -> ['Vindaloo - Prawn'] (0.4641797371767698)
# ['Korma - Lamb', 'Vindaloo - Prawn'] -> ['Special Fried Rice'] (0.47015886646629457)
# ['Special Fried Rice', 'Vindaloo - Prawn'] -> ['Korma - Lamb'] (0.461441213653603)
# ['Bhuna - Chicken', 'House white wine 75cl'] -> ['Plain Rice'] (0.45967042497831745)
# ['Bhuna - Chicken', 'Plain Rice'] -> ['House white wine 75cl'] (0.45630650021523894)
# ['House white wine 75cl', 'Plain Rice'] -> ['Bhuna - Chicken'] (0.4463157894736842)
# ['House white wine 75cl', 'Lamb Biryani'] -> ['Plain Rice'] (0.4724905501889962)
# ['House white wine 75cl', 'Plain Rice'] -> ['Lamb Biryani'] (0.47368421052631576)
# ['Lamb Biryani', 'Plain Rice'] -> ['House white wine 75cl'] (0.4669987546699875)
# ['Bhuna - Chicken', 'Chicken Tikka Balti'] -> ['Vindaloo - Prawn'] (0.4637618636755824)
# ['Bhuna - Chicken', 'Vindaloo - Prawn'] -> ['Chicken Tikka Balti'] (0.4570578231292517)
# ['Chicken Tikka Balti', 'Vindaloo - Prawn'] -> ['Bhuna - Chicken'] (0.4496026767043078)
# ['Bhuna - Chicken', 'Curry'] -> ['House white wine 75cl'] (0.4536671058410189)
# ['Bhuna - Chicken', 'House white wine 75cl'] -> ['Curry'] (0.4479618386816999)
# ['Curry', 'House white wine 75cl'] -> ['Bhuna - Chicken'] (0.4464131374243734)
# ['Chicken Tikka Balti', 'Lamb Biryani'] -> ['Special Fried Rice'] (0.46199575371549895)
# ['Chicken Tikka Balti', 'Special Fried Rice'] -> ['Lamb Biryani'] (0.45868465430016864)
# ['Lamb Biryani', 'Special Fried Rice'] -> ['Chicken Tikka Balti'] (0.4588781105018979)
# ['Bhuna - Chicken', 'House white wine 75cl'] -> ['Korma - Lamb'] (0.45143104943625323)
# ['Bhuna - Chicken', 'Korma - Lamb'] -> ['House white wine 75cl'] (0.4539904055822067)
# ['House white wine 75cl', 'Korma - Lamb'] -> ['Bhuna - Chicken'] (0.45280556763810353)
# ['Chicken Tikka Balti', 'Special Fried Rice'] -> ['Vindaloo - Prawn'] (0.4633220910623946)
# ['Chicken Tikka Balti', 'Vindaloo - Prawn'] -> ['Special Fried Rice'] (0.45964031785863657)
# ['Special Fried Rice', 'Vindaloo - Prawn'] -> ['Chicken Tikka Balti'] (0.4631268436578171)
# ['House white wine 75cl', 'Plain Rice'] -> ['Special Fried Rice'] (0.4686315789473684)
# ['House white wine 75cl', 'Special Fried Rice'] -> ['Plain Rice'] (0.46922428330522764)
# ['Plain Rice', 'Special Fried Rice'] -> ['House white wine 75cl'] (0.4688289806234204)
# ['Bhuna - Chicken', 'Korma - Lamb'] -> ['Special Fried Rice'] (0.4592237243785434)
# ['Bhuna - Chicken', 'Special Fried Rice'] -> ['Korma - Lamb'] (0.451931330472103)
# ['Korma - Lamb', 'Special Fried Rice'] -> ['Bhuna - Chicken'] (0.4463755828740992)
# ['Curry', 'Plain Rice'] -> ['Special Fried Rice'] (0.4669852302345786)
# ['Curry', 'Special Fried Rice'] -> ['Plain Rice'] (0.4566694987255735)
# ['Plain Rice', 'Special Fried Rice'] -> ['Curry'] (0.45282224094355517)
# ['Bhuna - Chicken', 'Special Fried Rice'] -> ['Vindaloo - Prawn'] (0.467381974248927)
# ['Bhuna - Chicken', 'Vindaloo - Prawn'] -> ['Special Fried Rice'] (0.4630102040816326)
# ['Special Fried Rice', 'Vindaloo - Prawn'] -> ['Bhuna - Chicken'] (0.4589127686472819)
# ['Bhuna - Chicken', 'Korma - Lamb'] -> ['Plain Rice'] (0.4461404273877017)
# ['Bhuna - Chicken', 'Plain Rice'] -> ['Korma - Lamb'] (0.4403788204907447)
# ['Korma - Lamb', 'Plain Rice'] -> ['Bhuna - Chicken'] (0.4390557939914163)
# ['Bhuna - Chicken', 'Curry'] -> ['Vindaloo - Prawn'] (0.4598155467720685)
# ['Bhuna - Chicken', 'Vindaloo - Prawn'] -> ['Curry'] (0.4451530612244898)
# ['Curry', 'Vindaloo - Prawn'] -> ['Bhuna - Chicken'] (0.4604221635883905)
# ['Bhuna - Chicken', 'Chicken Tikka Balti'] -> ['Lamb Biryani'] (0.46031061259706646)
# ['Bhuna - Chicken', 'Lamb Biryani'] -> ['Chicken Tikka Balti'] (0.4513536379018612)
# ['Chicken Tikka Balti', 'Lamb Biryani'] -> ['Bhuna - Chicken'] (0.45307855626326965)
# ['Chicken Tikka Balti', 'Korma - Lamb'] -> ['Lamb Biryani'] (0.47046323841903953)
# ['Chicken Tikka Balti', 'Lamb Biryani'] -> ['Korma - Lamb'] (0.47006369426751593)
# ['Korma - Lamb', 'Lamb Biryani'] -> ['Chicken Tikka Balti'] (0.4720682302771855)
# ['Lamb Biryani', 'Plain Rice'] -> ['Special Fried Rice'] (0.4578663345786633)
# ['Lamb Biryani', 'Special Fried Rice'] -> ['Plain Rice'] (0.46520455504006747)
# ['Plain Rice', 'Special Fried Rice'] -> ['Lamb Biryani'] (0.4646166807076664)
# ['Chicken Tikka Balti', 'House white wine 75cl'] -> ['Korma - Lamb'] (0.45549283543204516)
# ['Chicken Tikka Balti', 'Korma - Lamb'] -> ['House white wine 75cl'] (0.44581385465363366)
# ['House white wine 75cl', 'Korma - Lamb'] -> ['Chicken Tikka Balti'] (0.4562853414528056)
# ['Curry', 'Lamb Biryani'] -> ['Vindaloo - Prawn'] (0.452814219212865)
# ['Curry', 'Vindaloo - Prawn'] -> ['Lamb Biryani'] (0.47053649956024624)
# ['Lamb Biryani', 'Vindaloo - Prawn'] -> ['Curry'] (0.452240067624683)
# ['Bhuna - Chicken', 'Lamb Biryani'] -> ['Plain Rice'] (0.4589678510998308)
# ['Bhuna - Chicken', 'Plain Rice'] -> ['Lamb Biryani'] (0.4670684459750323)
# ['Lamb Biryani', 'Plain Rice'] -> ['Bhuna - Chicken'] (0.45039435450394355)
# ['Chicken Tikka Balti', 'Lamb Biryani'] -> ['Plain Rice'] (0.4602972399150743)
# ['Chicken Tikka Balti', 'Plain Rice'] -> ['Lamb Biryani'] (0.4527986633249791)
# ['Lamb Biryani', 'Plain Rice'] -> ['Chicken Tikka Balti'] (0.44997924449979243)
# ['Curry', 'Special Fried Rice'] -> ['Vindaloo - Prawn'] (0.4609175870858114)
# ['Curry', 'Vindaloo - Prawn'] -> ['Special Fried Rice'] (0.47713280562884786)
# ['Special Fried Rice', 'Vindaloo - Prawn'] -> ['Curry'] (0.45722713864306785)
# ['Curry', 'House white wine 75cl'] -> ['Korma - Lamb'] (0.46629213483146065)
# ['Curry', 'Korma - Lamb'] -> ['House white wine 75cl'] (0.4619006849315068)
# ['House white wine 75cl', 'Korma - Lamb'] -> ['Curry'] (0.46933449325793825)
# ['Bhuna - Chicken', 'Chicken Tikka Balti'] -> ['Curry'] (0.454702329594478)
# ['Bhuna - Chicken', 'Curry'] -> ['Chicken Tikka Balti'] (0.46288976723759334)
# ['Chicken Tikka Balti', 'Curry'] -> ['Bhuna - Chicken'] (0.45391903531438416)
# ['Chicken Tikka Balti', 'House white wine 75cl'] -> ['Special Fried Rice'] (0.47416413373860183)
# ['Chicken Tikka Balti', 'Special Fried Rice'] -> ['House white wine 75cl'] (0.46037099494097805)
# ['House white wine 75cl', 'Special Fried Rice'] -> ['Chicken Tikka Balti'] (0.46037099494097805)
# ['Curry', 'House white wine 75cl'] -> ['Plain Rice'] (0.4693171996542783)
# ['Curry', 'Plain Rice'] -> ['House white wine 75cl'] (0.47176368375325806)
# ['House white wine 75cl', 'Plain Rice'] -> ['Curry'] (0.4572631578947368)
# ['Bhuna - Chicken', 'Curry'] -> ['Korma - Lamb'] (0.45761967501097933)
# ['Bhuna - Chicken', 'Korma - Lamb'] -> ['Curry'] (0.45442651548190144)
# ['Curry', 'Korma - Lamb'] -> ['Bhuna - Chicken'] (0.4460616438356164)
# ['Chicken Tikka Balti', 'Curry'] -> ['Special Fried Rice'] (0.4689922480620155)
# ['Chicken Tikka Balti', 'Special Fried Rice'] -> ['Curry'] (0.459106239460371)
# ['Curry', 'Special Fried Rice'] -> ['Chicken Tikka Balti'] (0.46261682242990654)
# ['Chicken Tikka Balti', 'Curry'] -> ['Korma - Lamb'] (0.47459086993970717)
# ['Chicken Tikka Balti', 'Korma - Lamb'] -> ['Curry'] (0.46833829154271145)
# ['Curry', 'Korma - Lamb'] -> ['Chicken Tikka Balti'] (0.4717465753424658)
# ['Bhuna - Chicken', 'Curry'] -> ['Special Fried Rice'] (0.466403162055336)
# ['Bhuna - Chicken', 'Special Fried Rice'] -> ['Curry'] (0.455793991416309)
# ['Curry', 'Special Fried Rice'] -> ['Bhuna - Chicken'] (0.4511469838572642)
# ['House white wine 75cl', 'Korma - Lamb'] -> ['Vindaloo - Prawn'] (0.46367986080904744)
# ['House white wine 75cl', 'Vindaloo - Prawn'] -> ['Korma - Lamb'] (0.4571183533447684)
# ['Korma - Lamb', 'Vindaloo - Prawn'] -> ['House white wine 75cl'] (0.45770717045942466)
# ['Lamb Biryani', 'Special Fried Rice'] -> ['Vindaloo - Prawn'] (0.46014339940953186)
# ['Lamb Biryani', 'Vindaloo - Prawn'] -> ['Special Fried Rice'] (0.4611158072696534)
# ['Special Fried Rice', 'Vindaloo - Prawn'] -> ['Lamb Biryani'] (0.45975558364938895)
# ['Curry', 'Korma - Lamb'] -> ['Vindaloo - Prawn'] (0.4541952054794521)
# ['Curry', 'Vindaloo - Prawn'] -> ['Korma - Lamb'] (0.4665787159190853)
# ['Korma - Lamb', 'Vindaloo - Prawn'] -> ['Curry'] (0.45556032632030913)
# ['Bhuna - Chicken', 'Korma - Lamb'] -> ['Lamb Biryani'] (0.45311818578281726)
# ['Bhuna - Chicken', 'Lamb Biryani'] -> ['Korma - Lamb'] (0.43950930626057527)
# ['Korma - Lamb', 'Lamb Biryani'] -> ['Bhuna - Chicken'] (0.4430703624733475)
# ['Bhuna - Chicken', 'Plain Rice'] -> ['Special Fried Rice'] (0.4636246233318984)
# ['Bhuna - Chicken', 'Special Fried Rice'] -> ['Plain Rice'] (0.46223175965665236)
# ['Plain Rice', 'Special Fried Rice'] -> ['Bhuna - Chicken'] (0.45366470092670597)
# ['Korma - Lamb', 'Lamb Biryani'] -> ['Plain Rice'] (0.4673773987206823)
# ['Korma - Lamb', 'Plain Rice'] -> ['Lamb Biryani'] (0.4703862660944206)
# ['Lamb Biryani', 'Plain Rice'] -> ['Korma - Lamb'] (0.45496056454960565)
# ['Bhuna - Chicken', 'House white wine 75cl'] -> ['Special Fried Rice'] (0.4640069384215091)
# ['Bhuna - Chicken', 'Special Fried Rice'] -> ['House white wine 75cl'] (0.4592274678111588)
# ['House white wine 75cl', 'Special Fried Rice'] -> ['Bhuna - Chicken'] (0.45109612141652616)
# ['Korma - Lamb', 'Lamb Biryani'] -> ['Vindaloo - Prawn'] (0.455863539445629)
# ['Korma - Lamb', 'Vindaloo - Prawn'] -> ['Lamb Biryani'] (0.45899527694289394)
# ['Lamb Biryani', 'Vindaloo - Prawn'] -> ['Korma - Lamb'] (0.4518174133558749)
# ['Lamb Biryani', 'Plain Rice'] -> ['Vindaloo - Prawn'] (0.44582814445828145)
# ['Lamb Biryani', 'Vindaloo - Prawn'] -> ['Plain Rice'] (0.4539306846999155)
# ['Plain Rice', 'Vindaloo - Prawn'] -> ['Lamb Biryani'] (0.45221052631578945)
# ['House white wine 75cl', 'Korma - Lamb'] -> ['Lamb Biryani'] (0.4758590691605046)
# ['House white wine 75cl', 'Lamb Biryani'] -> ['Korma - Lamb'] (0.4594708105837883)
# ['Korma - Lamb', 'Lamb Biryani'] -> ['House white wine 75cl'] (0.46652452025586355)
# ['Chicken Tikka Balti', 'Curry'] -> ['Plain Rice'] (0.46124031007751937)
# ['Chicken Tikka Balti', 'Plain Rice'] -> ['Curry'] (0.4473684210526316)
# ['Curry', 'Plain Rice'] -> ['Chicken Tikka Balti'] (0.46524761077324067)
# ['Curry', 'Lamb Biryani'] -> ['Special Fried Rice'] (0.4815911976301312)
# ['Curry', 'Special Fried Rice'] -> ['Lamb Biryani'] (0.48343245539507224)
# ['Lamb Biryani', 'Special Fried Rice'] -> ['Curry'] (0.4799662589624631)
# ['Korma - Lamb', 'Plain Rice'] -> ['Vindaloo - Prawn'] (0.4648068669527897)
# ['Korma - Lamb', 'Vindaloo - Prawn'] -> ['Plain Rice'] (0.46500644053241735)
# ['Plain Rice', 'Vindaloo - Prawn'] -> ['Korma - Lamb'] (0.456)
# ['Curry', 'Lamb Biryani'] -> ['Plain Rice'] (0.4633939906898011)
# ['Curry', 'Plain Rice'] -> ['Lamb Biryani'] (0.47567332754126845)
# ['Lamb Biryani', 'Plain Rice'] -> ['Curry'] (0.45454545454545453)
# ['Bhuna - Chicken', 'Lamb Biryani'] -> ['Special Fried Rice'] (0.4538917089678511)
# ['Bhuna - Chicken', 'Special Fried Rice'] -> ['Lamb Biryani'] (0.46051502145922746)
# ['Lamb Biryani', 'Special Fried Rice'] -> ['Bhuna - Chicken'] (0.45255166596372837)
# ['Chicken Tikka Balti', 'Curry'] -> ['House white wine 75cl'] (0.4595176571920758)
# ['Chicken Tikka Balti', 'House white wine 75cl'] -> ['Curry'] (0.46330872774641774)
# ['Curry', 'House white wine 75cl'] -> ['Chicken Tikka Balti'] (0.4611063094209162)
# ['House white wine 75cl', 'Korma - Lamb'] -> ['Plain Rice'] (0.471509351892127)
# ['House white wine 75cl', 'Plain Rice'] -> ['Korma - Lamb'] (0.45642105263157895)
# ['Korma - Lamb', 'Plain Rice'] -> ['House white wine 75cl'] (0.4652360515021459)
# ['Chicken Tikka Balti', 'Curry'] -> ['Vindaloo - Prawn'] (0.4595176571920758)
# ['Chicken Tikka Balti', 'Vindaloo - Prawn'] -> ['Curry'] (0.4462567963195316)
# ['Curry', 'Vindaloo - Prawn'] -> ['Chicken Tikka Balti'] (0.46921723834652596)
# ['Chicken Tikka Balti', 'Curry'] -> ['Lamb Biryani'] (0.46554694229112836)
# ['Chicken Tikka Balti', 'Lamb Biryani'] -> ['Curry'] (0.45902335456475585)
# ['Curry', 'Lamb Biryani'] -> ['Chicken Tikka Balti'] (0.4574693186627169)
# ['Curry', 'House white wine 75cl'] -> ['Lamb Biryani'] (0.4727744165946413)
# ['Curry', 'Lamb Biryani'] -> ['House white wine 75cl'] (0.46297079983072364)
# ['House white wine 75cl', 'Lamb Biryani'] -> ['Curry'] (0.4594708105837883)
# ['Curry', 'House white wine 75cl'] -> ['Vindaloo - Prawn'] (0.4567847882454624)
# ['Curry', 'Vindaloo - Prawn'] -> ['House white wine 75cl'] (0.4648197009674582)
# ['House white wine 75cl', 'Vindaloo - Prawn'] -> ['Curry'] (0.4532590051457976)
# ['Curry', 'Korma - Lamb'] -> ['Special Fried Rice'] (0.4755993150684932)
# ['Curry', 'Special Fried Rice'] -> ['Korma - Lamb'] (0.4719626168224299)
# ['Korma - Lamb', 'Special Fried Rice'] -> ['Curry'] (0.47096227214921577)
# ['Bhuna - Chicken', 'Curry'] -> ['Lamb Biryani'] (0.46464646464646464)
# ['Bhuna - Chicken', 'Lamb Biryani'] -> ['Curry'] (0.44754653130287647)
# ['Curry', 'Lamb Biryani'] -> ['Bhuna - Chicken'] (0.44773592890393565)
# ['House white wine 75cl', 'Plain Rice'] -> ['Vindaloo - Prawn'] (0.4648421052631579)
# ['House white wine 75cl', 'Vindaloo - Prawn'] -> ['Plain Rice'] (0.4734133790737564)
# ['Plain Rice', 'Vindaloo - Prawn'] -> ['House white wine 75cl'] (0.4648421052631579)
# ['Bhuna - Chicken', 'Korma - Lamb'] -> ['Vindaloo - Prawn'] (0.4670737025730484)
# ['Bhuna - Chicken', 'Vindaloo - Prawn'] -> ['Korma - Lamb'] (0.45535714285714285)
# ['Korma - Lamb', 'Vindaloo - Prawn'] -> ['Bhuna - Chicken'] (0.45985401459854014)
# ['Curry', 'Korma - Lamb'] -> ['Plain Rice'] (0.4490582191780822)
# ['Curry', 'Plain Rice'] -> ['Korma - Lamb'] (0.45569070373588183)
# ['Korma - Lamb', 'Plain Rice'] -> ['Curry'] (0.45021459227467814)
# ['Curry', 'Plain Rice'] -> ['Vindaloo - Prawn'] (0.4522154648132059)
# ['Curry', 'Vindaloo - Prawn'] -> ['Plain Rice'] (0.4577836411609499)
# ['Plain Rice', 'Vindaloo - Prawn'] -> ['Curry'] (0.4383157894736842)
# ['Chicken Tikka Balti', 'House white wine 75cl'] -> ['Lamb Biryani'] (0.4654798089448545)
# ['Chicken Tikka Balti', 'Lamb Biryani'] -> ['House white wine 75cl'] (0.45520169851380043)
# ['House white wine 75cl', 'Lamb Biryani'] -> ['Chicken Tikka Balti'] (0.4502309953800924)
# ['Bhuna - Chicken', 'Chicken Tikka Balti'] -> ['Korma - Lamb'] (0.45340811044003454)
# ['Bhuna - Chicken', 'Korma - Lamb'] -> ['Chicken Tikka Balti'] (0.45835150457915397)
# ['Chicken Tikka Balti', 'Korma - Lamb'] -> ['Bhuna - Chicken'] (0.4466638334041649)
# ['Chicken Tikka Balti', 'Korma - Lamb'] -> ['Special Fried Rice'] (0.4670633234169146)
# ['Chicken Tikka Balti', 'Special Fried Rice'] -> ['Korma - Lamb'] (0.4633220910623946)
# ['Korma - Lamb', 'Special Fried Rice'] -> ['Chicken Tikka Balti'] (0.4658753709198813)
# ['Chicken Tikka Balti', 'Plain Rice'] -> ['Vindaloo - Prawn'] (0.462406015037594)
# ['Chicken Tikka Balti', 'Vindaloo - Prawn'] -> ['Plain Rice'] (0.4629861982434128)
# ['Plain Rice', 'Vindaloo - Prawn'] -> ['Chicken Tikka Balti'] (0.46610526315789474)
# ['Korma - Lamb', 'Plain Rice'] -> ['Special Fried Rice'] (0.47467811158798284)
# ['Korma - Lamb', 'Special Fried Rice'] -> ['Plain Rice'] (0.4688427299703264)
# ['Plain Rice', 'Special Fried Rice'] -> ['Korma - Lamb'] (0.4658803706823926)
# ['House white wine 75cl', 'Lamb Biryani'] -> ['Special Fried Rice'] (0.4741705165896682)
# ['House white wine 75cl', 'Special Fried Rice'] -> ['Lamb Biryani'] (0.4759696458684654)
# ['Lamb Biryani', 'Special Fried Rice'] -> ['House white wine 75cl'] (0.47617039223956137)
# ['Bhuna - Chicken', 'Chicken Tikka Balti'] -> ['Special Fried Rice'] (0.4641932700603969)
# ['Bhuna - Chicken', 'Special Fried Rice'] -> ['Chicken Tikka Balti'] (0.46180257510729616)
# ['Chicken Tikka Balti', 'Special Fried Rice'] -> ['Bhuna - Chicken'] (0.4536256323777403)
# ['Bhuna - Chicken', 'House white wine 75cl'] -> ['Vindaloo - Prawn'] (0.4614050303555941)
# ['Bhuna - Chicken', 'Vindaloo - Prawn'] -> ['House white wine 75cl'] (0.4523809523809524)
# ['House white wine 75cl', 'Vindaloo - Prawn'] -> ['Bhuna - Chicken'] (0.4562607204116638)
# ['Korma - Lamb', 'Lamb Biryani'] -> ['Special Fried Rice'] (0.4695095948827292)
# ['Korma - Lamb', 'Special Fried Rice'] -> ['Lamb Biryani'] (0.46672318779143707)
# ['Lamb Biryani', 'Special Fried Rice'] -> ['Korma - Lamb'] (0.4643610291016449)
# ['Chicken Tikka Balti', 'Korma - Lamb'] -> ['Plain Rice'] (0.45898852528686784)
# ['Chicken Tikka Balti', 'Plain Rice'] -> ['Korma - Lamb'] (0.45112781954887216)
# ['Korma - Lamb', 'Plain Rice'] -> ['Chicken Tikka Balti'] (0.463519313304721)
# ['Bhuna - Chicken', 'Plain Rice'] -> ['Vindaloo - Prawn'] (0.4662074903142488)
# ['Bhuna - Chicken', 'Vindaloo - Prawn'] -> ['Plain Rice'] (0.4604591836734694)
# ['Plain Rice', 'Vindaloo - Prawn'] -> ['Bhuna - Chicken'] (0.456)
# ['Plain Rice', 'Special Fried Rice'] -> ['Vindaloo - Prawn'] (0.4700926705981466)
# ['Plain Rice', 'Vindaloo - Prawn'] -> ['Special Fried Rice'] (0.46989473684210525)
# ['Special Fried Rice', 'Vindaloo - Prawn'] -> ['Plain Rice'] (0.47029077117572693)
# ['Curry', 'Korma - Lamb'] -> ['Lamb Biryani'] (0.4636130136986301)
# ['Curry', 'Lamb Biryani'] -> ['Korma - Lamb'] (0.45831570038087177)
# ['Korma - Lamb', 'Lamb Biryani'] -> ['Curry'] (0.46183368869936037)
# ['Chicken Tikka Balti', 'Lamb Biryani'] -> ['Vindaloo - Prawn'] (0.4653927813163482)
# ['Chicken Tikka Balti', 'Vindaloo - Prawn'] -> ['Lamb Biryani'] (0.45838561271434547)
# ['Lamb Biryani', 'Vindaloo - Prawn'] -> ['Chicken Tikka Balti'] (0.463229078613694)
# ['Bhuna - Chicken', 'Lamb Biryani'] -> ['Vindaloo - Prawn'] (0.45981387478849406)
# ['Bhuna - Chicken', 'Vindaloo - Prawn'] -> ['Lamb Biryani'] (0.46215986394557823)
# ['Lamb Biryani', 'Vindaloo - Prawn'] -> ['Bhuna - Chicken'] (0.45942519019442096)
# ['Chicken Tikka Balti', 'House white wine 75cl'] -> ['Plain Rice'] (0.46808510638297873)
# ['Chicken Tikka Balti', 'Plain Rice'] -> ['House white wine 75cl'] (0.4502923976608187)
# ['House white wine 75cl', 'Plain Rice'] -> ['Chicken Tikka Balti'] (0.45389473684210524)
# ['Chicken Tikka Balti', 'House white wine 75cl'] -> ['Vindaloo - Prawn'] (0.4685193226226661)
# ['Chicken Tikka Balti', 'Vindaloo - Prawn'] -> ['House white wine 75cl'] (0.45127561689669593)
# ['House white wine 75cl', 'Vindaloo - Prawn'] -> ['Chicken Tikka Balti'] (0.46269296740994853)
# ['Curry', 'House white wine 75cl'] -> ['Special Fried Rice'] (0.4762316335350043)
# ['Curry', 'Special Fried Rice'] -> ['House white wine 75cl'] (0.46813933729821583)
# ['House white wine 75cl', 'Special Fried Rice'] -> ['Curry'] (0.4645868465430017)
# ['Bhuna - Chicken', 'Chicken Tikka Balti'] -> ['Plain Rice'] (0.4641932700603969)
# ['Bhuna - Chicken', 'Plain Rice'] -> ['Chicken Tikka Balti'] (0.46319414550150667)
# ['Chicken Tikka Balti', 'Plain Rice'] -> ['Bhuna - Chicken'] (0.4494569757727652)
# ['Bhuna - Chicken', 'House white wine 75cl'] -> ['Lamb Biryani'] (0.47181266261925414)
# ['Bhuna - Chicken', 'Lamb Biryani'] -> ['House white wine 75cl'] (0.4602368866328257)
# ['House white wine 75cl', 'Lamb Biryani'] -> ['Bhuna - Chicken'] (0.45695086098278037)
# ['House white wine 75cl', 'Korma - Lamb'] -> ['Special Fried Rice'] (0.4675946063505872)
# ['House white wine 75cl', 'Special Fried Rice'] -> ['Korma - Lamb'] (0.45320404721753793)
# ['Korma - Lamb', 'Special Fried Rice'] -> ['House white wine 75cl'] (0.4557015684612124)
# ['Bhuna - Chicken', 'Chicken Tikka Balti'] -> ['House white wine 75cl'] (0.4486626402070751)
# ['Bhuna - Chicken', 'House white wine 75cl'] -> ['Chicken Tikka Balti'] (0.45099739809193407)
# ['Chicken Tikka Balti', 'House white wine 75cl'] -> ['Bhuna - Chicken'] (0.4515848892748589)
# ['Chicken Tikka Balti', 'Korma - Lamb'] -> ['Vindaloo - Prawn'] (0.47046323841903953)
# ['Chicken Tikka Balti', 'Vindaloo - Prawn'] -> ['Korma - Lamb'] (0.4629861982434128)
# ['Korma - Lamb', 'Vindaloo - Prawn'] -> ['Chicken Tikka Balti'] (0.4753112924001717)
# ['Bhuna - Chicken', 'Curry'] -> ['Plain Rice'] (0.4580588493631972)
# ['Bhuna - Chicken', 'Plain Rice'] -> ['Curry'] (0.4489883770985794)
# ['Curry', 'Plain Rice'] -> ['Bhuna - Chicken'] (0.4530842745438749)
# ['Chicken Tikka Balti', 'Plain Rice'] -> ['Special Fried Rice'] (0.4653299916457811)
# ['Chicken Tikka Balti', 'Special Fried Rice'] -> ['Plain Rice'] (0.46964586846543)
# ['Plain Rice', 'Special Fried Rice'] -> ['Chicken Tikka Balti'] (0.4692502106149958)
# 324 rules generated
